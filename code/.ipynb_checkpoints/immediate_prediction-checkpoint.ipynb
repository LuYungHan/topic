# %%
import serial
import csv
import time
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
np.random.seed(202205456)

data0506 = [
            "../0506data/手2022-05-06 114900-4.csv",
            "../0506data/手2022-05-06 113600-4.csv",
            "../0506data/手2022-05-06 115200-2.csv",
            "../0506data/腳2022-05-06 120000-4.csv",
            "../0506data/腳2022-05-06 120300-3.csv",
            "../0506data/腳2022-05-06 120500-4.csv",
            "./腳_1.csv"]
                                                    
data0510 = [
            "../0510data/手2022-05-10 103600.csv",
            "../0510data/手2022-05-10 103800.csv",
            "../0510data/手2022-05-10 104000.csv",
            "../0510data/腳2022-05-10 103600.csv",
            "../0510data/腳2022-05-10 103800.csv",
            "../0510data/腳2022-05-10 104000.csv"]

def RF(data,data1):
    data = np.array(pd.read_csv(data))
    labelSeries = data[:,16]
    dataSeries = data[:,1:3]+data[:,7:9]
    #x_train, x_test, y_train, y_test = train_test_split(dataSeries, labelSeries,test_size=0.2, random_state=222)
    data1 = np.array(pd.read_csv(data1))
    dataSeries1 = data1[:,1:3]+data1[:,7:9]
    #x_train1, x_test1, y_train1, y_test1 = train_test_split(dataSeries1, labelSeries1,test_size=0.2, random_state=222)

    randomForestModel = RandomForestClassifier(n_estimators=300 ,criterion = 'gini')
    # 使用訓練資料訓練模型
    #x_train=x_train.astype('int')
    #y_train=y_train.astype('str')
    #x_test=x_test.astype('int')
    #y_test=y_test.astype('str')
    randomForestModel.fit(dataSeries, labelSeries)
    # 使用訓練資料預測
    predict = randomForestModel.predict(dataSeries1)
#     RF_score = randomForestModel.score(dataSeries1,labelSeries1)
#     print(classification_report(labelSeries1,predict))
    return predict

# serialPort = serial.Serial(port='/dev/cu.usbmodem141101', baudrate=38400, timeout=2)#HC-05-1
# #serialPort2 = serial.Serial(port='COM70', baudrate=38400, timeout=2, parity=serial.PARITY_EVEN, stopbits=1)#HC-05-2
# #115200 esp32

# print("hello")
# #/dev/cu.name
# size = 1024
# xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
# #xg2,yg2,zg2,mx2,my2,mz2,xa2,ya2,za2,xq2,yq2,zq2,direc2,mytime2 =[],[],[],[],[],[],[],[],[],[],[],[],[],[]
# Ttime=str(datetime.now())
# print(Ttime)
# print(Ttime[17::])
# tt=0
# TT=59
# while(tt<=TT):
#     data = serialPort.readline().decode('utf-8', 'ignore')
# #     data2 = serialPort2.readline().decode('utf-8')
#     print(data)
# #     print(data2)
#     data=data.split(',')
# #     data2=data2.split(',')
# #     print(len(data),len(data2))
# #     print(float(str(datetime.now())[17::]))
#     if (float(str(datetime.now())[17::])< float(Ttime[17::])):      
#         tt = float(Ttime[17::])+60-float(str(datetime.now())[17::] )
#         if tt>=TT:
#             break
#     else:
#         tt = -float(Ttime[17::])+float(str(datetime.now())[17::] )
#         if tt>=TT:
#             break
#     if len(data)==16:
#         xg.append(data[1])
#         yg.append(data[2])
#         zg.append(data[3])
#         mx.append(data[4])
#         my.append(data[5])
#         mz.append(data[6])
#         xa.append(data[7])
#         ya.append(data[8])
#         za.append(data[9])
#         xq.append(data[10])
#         yq.append(data[11])
#         zq.append(data[12])
#         direc.append(data[13])
#         mytime.append(data[14])
# #     if len(data2)==16:
# #         xg2.append(data2[1])
# #         yg2.append(data2[2])
# #         zg2.append(data2[3])
# #         mx2.append(data2[4])
# #         my2.append(data2[5])
# #         mz2.append(data2[6])
# #         xa2.append(data2[7])
# #         ya2.append(data2[8])
# #         za2.append(data2[9])
# #         xq2.append(data2[10])
# #         yq2.append(data2[11])
# #         zq2.append(data2[12])
# #         direc2.append(data2[13])
# #         mytime2.append(data2[14])
        
# pandasData={"Xg":xg,"Yg":yg,"Zg":zg,"Xm":mx,"Ym":my,"Zm":mz,"Xa":xa,"Ya":ya,"Za":za,"Xq":xq,"Yq":yq,"Zq":zq,"Direction":direc,"Time":mytime}
# # pandasData1={xg,yg,zg,mx,my,mz,xa,ya,za,xq,yq,zq,direc,mytime}
# # pandasData2={"Xg":xg2,"Yg":yg2,"Zg":zg2,"Xm":mx2,"Ym":my2,"Zm":mz2,"Xa":xa2,"Ya":ya2,"Za":za2,"Xq":xq2,"Yq":yq2,"Zq":zq2,"Direction":direc2,"Time":mytime2}
# df = pd.DataFrame(pandasData)
# #df2= pd.DataFrame(pandasData2)
# print(df)
# #print(df2)

# df.to_csv('腳_1'+'.csv')
#df2.to_csv('手'+datetime.now().strftime('%Y-%m-%d %H%M%S')+'.csv')
print("--------------------------------\nRandomForest\n-------------------------------")
#for i in range(len(data0506)//2):
for i in range(1):
    print("Hand:",RF(data0506[i],data0506[2]))
    print("")
    dff = pd.DataFrame(RF(data0506[i],data0506[2]))
#     print("Foot:",RF(data0506[i+2],data0506[i+3]))
#     print("________________________________________________________")
dff.to_csv('label_1'+'.csv')
# serialPort.close()
#serialPort2.close()
# Out:
# --------------------------------
# RandomForest
# -------------------------------
# Hand: ['W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'W' 'T'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W'
#  'T' 'T' 'W' 'W' 'W' 'W' 'T' 'W' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'T'
#  'T' 'T' 'T' 'W' 'W' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W'
#  'W' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T'
#  'T' 'T' 'T' 'T' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'W' 'W' 'W' 'T' 'T' 'T' 'W' 'W' 'T'
#  'T' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'W' 'T'
#  'W' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'W'
#  'W' 'T' 'W' 'W' 'T' 'T' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'T' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'W' 'W' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T'
#  'W' 'W' 'W' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'W' 'T' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'W' 'W' 'W' 'T' 'T' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'W'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W'
#  'T' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'W'
#  'T' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'W' 'T' 'T' 'W' 'T' 'W' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T'
#  'T' 'T' 'W' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'W' 'T' 'W' 'W' 'W' 'W' 'W' 'T' 'W' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W'
#  'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'W' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'W' 'T' 'T' 'T' 'W' 'W' 'T' 'W']
